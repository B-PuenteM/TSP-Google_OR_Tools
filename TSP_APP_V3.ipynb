# %% [markdown]
# ## Bienvenido a la aplicación de generación de rutas CATENA-USFQ. Para comenzar siga los siguientes pasos:
#
# Al hacer click en el mapa desplegado abajo se mostrará la ubicación seleccionada en "latitud" y "longitud".
# 1. Haga click en la ubicación del lugar central desde donde sale a hacer las entregas.
# 2. Copie los valores encontrados de latitud y longitud y peguelos en la caja de texto "Ubicación:" debajo del mapa. Pegue ambos valores separados por una coma y presione enter, por ejemplo: -0.181030, -78.484018
# 3. De la misma forma que seleccionó su ubicación central de despacho, seleccione los puntos de entrega en el mapa e ingréselos en la caja de texto en el mismo formato (latitud y longitud separado por coma), y presione enter. Puede ingresar cuantos puntos desee. Para terminar ingrese la palabra "FIN".

# %%
from __future__ import print_function
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from scipy.spatial import distance
from statistics import mean
from geopy.distance import geodesic 
import pandas as pd
import folium
from TSP_APP_V2 import Ejecutar_Programa #Importa el programa que se alberga en el archivo TSP_APP_V2.py
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Ingrese sus ubicaciones comenzando por su lugar central. Para terminar ingrese la palabra "FIN":
#
# -0.164004,-78.480887
# Punto:  [-0.164004, -78.480887]  registrado correctamente.
#
# -0.095974,-78.420235
# Punto:  [-0.095974, -78.420235]  registrado correctamente.
#
# -0.122436,-78.468053
# Punto:  [-0.122436, -78.468053]  registrado correctamente.
#
# -0.14672,-78.493725
# Punto:  [-0.14672, -78.493725]  registrado correctamente.
#
# -0.181442,-78.495507
# Punto:  [-0.181442, -78.495507]  registrado correctamente.
#
# -0.207169,-78.483263
# Punto:  [-0.207169, -78.483263]  registrado correctamente.
#
# -0.217262,-78.513866
# Punto:  [-0.217262, -78.513866]  registrado correctamente.
#
# -0.283393,-78.560091
# Punto:  [-0.283393, -78.560091]  registrado correctamente.
#
# -0.293279,-78.476979
# Punto:  [-0.293279, -78.476979]  registrado correctamente.
#
# -0.331962,-78.445971
# Punto:  [-0.331962, -78.445971]  registrado correctamente.
#
# -0.201451,-78.440983
# Punto:  [-0.201451, -78.440983]  registrado correctamente.
#
# -0.214299,-78.43543
# Punto:  [-0.214299, -78.43543]  registrado correctamente.
#
# -0.208994,-78.428112
# Punto:  [-0.208994, -78.428112]  registrado correctamente.
#
# -0.212619,-78.404898
# Punto:  [-0.212619, -78.404898]  registrado correctamente.
#
# FIN
# Los puntos a considerar para la optimziación son:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Objective: 76.42 km
# Route for vehicle 0:
#  0 -> 3 -> 2 -> 1 -> 10 -> 11 -> 12 -> 13 -> 9 -> 8 -> 7 -> 6 -> 5 -> 4 -> 0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#-0.2281,-78.3370
#-0.2130,-78.4063
#-0.2131,-78.4309
#-0.1823,-78.4402
#-0.2018,-78.4767
#-0.2061,-78.4853
#-0.2210,-78.5143
#-0.1372,-78.5009
